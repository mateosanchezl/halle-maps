# %%
import pandas as pd

# %%
df = pd.read_csv("pcv_final.csv")

# %%
df.head()
# Out:
#    parent    id                      Performance Title composer_text  \
# 0       1   101               Der Freischutz; Overture         Weber
# 1       1  1798                      Symphony No1 in C     Beethoven
# 2       1  2987  Symphony in E flat; Andante in A flat        Mozart
# 3       1  3950                    The Syren; Overture         Auber
# 4       1  3952         The Siege of Corinth; Overture       Rossini
#
#                    Concert Title  original_date  date_start  \
# 0  1st Concert of the 1st Season  30th Jan 1858  1858-01-30
# 1  1st Concert of the 1st Season  30th Jan 1858  1858-01-30
# 2  1st Concert of the 1st Season  30th Jan 1858  1858-01-30
# 3  1st Concert of the 1st Season  30th Jan 1858  1858-01-30
# 4  1st Concert of the 1st Season  30th Jan 1858  1858-01-30
#
#                 orchestra       Venue Name  Venue Town  \
# 0  Hallé Orchestra; 1857-  Free Trade Hall  Manchester
# 1  Hallé Orchestra; 1857-  Free Trade Hall  Manchester
# 2  Hallé Orchestra; 1857-  Free Trade Hall  Manchester
# 3  Hallé Orchestra; 1857-  Free Trade Hall  Manchester
# 4  Hallé Orchestra; 1857-  Free Trade Hall  Manchester
#
#                   seonametown
# 0  manchester-free-trade-hall
# 1  manchester-free-trade-hall
# 2  manchester-free-trade-hall
# 3  manchester-free-trade-hall
# 4  manchester-free-trade-hall

# %%
df.nunique()
# Out:
# parent                8149
# id                   37217
# Performance Title     8145
# composer_text         1368
# Concert Title          793
# original_date         7804
# date_start            7784
# orchestra               58
# Venue Name             254
# Venue Town             262
# seonametown            378
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37217 entries, 0 to 37216
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   parent             37217 non-null  int64
#  1   id                 37217 non-null  int64
#  2   Performance Title  37216 non-null  object
#  3   composer_text      37202 non-null  object
#  4   Concert Title      6098 non-null   object
#  5   original_date      37217 non-null  object
#  6   date_start         37217 non-null  object
#  7   orchestra          37217 non-null  object
#  8   Venue Name         37217 non-null  object
#  9   Venue Town         37217 non-null  object
#  10  seonametown        37217 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 3.1+ MB

# %%
df.drop("Concert Title", axis=1, inplace=True)

# %%
df = df[~df.isna().any(axis=1)]

# %%
df = df[df["Venue Name"] != 'unlisted']

# %%
# Create a nested structure as described
grouped = df.groupby(['Venue Name', 'Venue Town', 'parent', 'date_start'])

# Create a structured dictionary for each group
def make_concert_info(group):
    performances = []
    for _, row in group.iterrows():
        performances.append({
            "title": row['Performance Title'],
            "composer": row['composer_text'],
            "orchestra": row['orchestra']
        })
    return performances

# Apply the function to group data
concerts = grouped.apply(make_concert_info).reset_index(name='performances')
concerts.rename(columns={'parent': 'concert_id', 'date_start': 'date'}, inplace=True)

# Organizing concerts under venues
venues = concerts.groupby(['Venue Name', 'Venue Town']).apply(lambda x: x[['concert_id', 'date', 'performances']].to_dict('records')).reset_index(name='concerts')
print(venues.head())
# Out:
#         Venue Name   Venue Town  \
# 0       ABC Cinema  Northampton
# 1      ABC Theatre    Blackpool
# 2     Abbey Cinema      Wexford
# 3       Abbey Road       London
# 4  Adam Smith Hall     Kirkaldy
#
#                                             concerts
# 0  [{'concert_id': 6162, 'date': '1969-03-02', 'p...
# 1  [{'concert_id': 7143, 'date': '1976-06-06', 'p...
# 2  [{'concert_id': 4394, 'date': '1958-10-26', 'p...
# 3  [{'concert_id': 2555, 'date': '1948-12-02', 'p...
# 4  [{'concert_id': 1964, 'date': '1946-06-19', 'p...

# %%
# Function to count unique concerts per venue
def count_unique_concerts(concert_list):
    # Extract concert_id from each concert and count unique IDs
    concert_ids = {concert['concert_id'] for concert in concert_list}
    return len(concert_ids)

# Apply the function to each row in the 'concerts' column
venues['concert_count'] = venues['concerts'].apply(count_unique_concerts)

# Output the updated DataFrame
print(venues[['Venue Name', 'Venue Town', 'concert_count']])
# Out:
#           Venue Name   Venue Town  concert_count
# 0         ABC Cinema  Northampton              1
# 1        ABC Theatre    Blackpool              1
# 2       Abbey Cinema      Wexford              1
# 3         Abbey Road       London             20
# 4    Adam Smith Hall     Kirkaldy              5
# ..               ...          ...            ...
# 370   Winter Gardens  Bournemouth             10
# 371   Winter Gardens   Eastbourne              1
# 372   Winter Gardens      Malvern              1
# 373   Winter Gardens      Margate              3
# 374   Winter Gardens    Morecambe              6
#
# [375 rows x 3 columns]

# %%
# Get summary statistics for concert counts
summary_stats = venues['concert_count'].describe()
print(summary_stats)

# If you need additional statistics, such as the median explicitly
median = venues['concert_count'].median()
print(f'Median number of concerts: {median}'
      f'Minimum number of concerts: {summary_stats["min"]}'
      f'Maximum number of concerts: {summary_stats["max"]}')
# Out:
# count     375.000000
# mean       21.712000
# std       174.955311
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         6.000000
# max      3221.000000
# Name: concert_count, dtype: float64
# Median number of concerts: 2.0Minimum number of concerts: 1.0Maximum number of concerts: 3221.0

# %%
max_concerts = venues['concert_count'].max()
max_venues = venues[venues['concert_count'] == max_concerts]
print(max_venues)
# Out:
#           Venue Name  Venue Town  \
# 120  Free Trade Hall  Manchester
#
#                                               concerts  concert_count
# 120  [{'concert_id': 1, 'date': '1858-01-30', 'perf...           3221

# %%
venues
# Out:
#           Venue Name   Venue Town  \
# 0         ABC Cinema  Northampton
# 1        ABC Theatre    Blackpool
# 2       Abbey Cinema      Wexford
# 3         Abbey Road       London
# 4    Adam Smith Hall     Kirkaldy
# ..               ...          ...
# 370   Winter Gardens  Bournemouth
# 371   Winter Gardens   Eastbourne
# 372   Winter Gardens      Malvern
# 373   Winter Gardens      Margate
# 374   Winter Gardens    Morecambe
#
#                                               concerts  concert_count
# 0    [{'concert_id': 6162, 'date': '1969-03-02', 'p...              1
# 1    [{'concert_id': 7143, 'date': '1976-06-06', 'p...              1
# 2    [{'concert_id': 4394, 'date': '1958-10-26', 'p...              1
# 3    [{'concert_id': 2555, 'date': '1948-12-02', 'p...             20
# 4    [{'concert_id': 1964, 'date': '1946-06-19', 'p...              5
# ..                                                 ...            ...
# 370  [{'concert_id': 3042, 'date': '1952-06-06', 'p...             10
# 371  [{'concert_id': 2503, 'date': '1949-05-28', 'p...              1
# 372  [{'concert_id': 7500, 'date': '1978-06-04', 'p...              1
# 373  [{'concert_id': 4939, 'date': '1962-04-29', 'p...              3
# 374  [{'concert_id': 2196, 'date': '1947-01-19', 'p...              6
#
# [375 rows x 4 columns]

# %%
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import time

# Initialize the geocoder with a specific user_agent
geolocator = Nominatim(user_agent="my_geocode_app")

# Define a rate limiter to manage request rates
geocode_with_delay = RateLimiter(geolocator.geocode, min_delay_seconds=1, error_wait_seconds=10)

def geocode_venue(row):
    try:
        # Combining venue name and town for a more precise geocode
        search_query = f"{row['Venue Name']}, {row['Venue Town']}"
        location = geocode_with_delay(search_query)
        if location:
            print(f"Geocoded: {search_query} -> Latitude: {location.latitude}, Longitude: {location.longitude}")
            return location.latitude, location.longitude
        else:
            print(f"Location not found: {search_query}")
            return None, None
    except Exception as e:
        print(f"Error geocoding {search_query}: {e}")
        return None, None

# Apply the geocoding function to the venues DataFrame
venues[['latitude', 'longitude']] = venues.apply(geocode_venue, axis=1, result_type='expand')

# Display the DataFrame to confirm coordinates are added
print(venues)
# Out:
# Location not found: ABC Cinema, Northampton
# Location not found: ABC Theatre, Blackpool
# Location not found: Abbey Cinema, Wexford
# Geocoded: Abbey Road, London -> Latitude: 51.5325414, Longitude: 0.0036092
# Location not found: Adam Smith Hall, Kirkaldy
# Geocoded: Albert Hall, Manchester -> Latitude: 53.478299050000004, Longitude: -2.247901788881243
# Geocoded: Albert Hall, Nottingham -> Latitude: 52.954312, Longitude: -1.156231121262001
# Location not found: Arcadia Theatre, Llandudno
# Geocoded: Ashton Hall, Lancaster -> Latitude: 54.0088778, Longitude: -2.8227046930252007
# Geocoded: Assembly Hall, Tunbridge Wells -> Latitude: 51.13257285, Longitude: 0.2645546442675571
# Geocoded: Assembly Hall, Walthamstow -> Latitude: 51.5908778, Longitude: -0.012399405402629649
# Location not found: Assembly Hall, Wembley
# Geocoded: Assembly Rooms, Derby -> Latitude: 52.923651250000006, Longitude: -1.476435354528702
# Location not found: Auditorium der Universitat, Regensburg
# Geocoded: BASF, Ludwigshafen -> Latitude: 49.51824095, Longitude: 8.421278202611429
# Geocoded: BBC Studios, London -> Latitude: 51.511135499999995, Longitude: -0.22510766742459215
# Location not found: Barrfields Pavilion, Largs
# Location not found: Baths Hall, Darlington
# Geocoded: Beaulieu Theatre, Lausanne -> Latitude: 46.5295577, Longitude: 6.622904702485964
# Location not found: Beehive Theatre, Darlington
# Geocoded: Beethovenhalle, Bonn -> Latitude: 50.74084645, Longitude: 7.105034876375994
# Geocoded: Belgrade Theatre, Coventry -> Latitude: 52.4098302, Longitude: -1.5143871070364272
# Geocoded: Brangwyn Hall, Swansea -> Latitude: 51.6136204, Longitude: -3.9602132334638434
# Geocoded: Broadway, Eccles -> Latitude: 53.4737779, Longitude: -2.3027509
# Geocoded: Caird Hall, Dundee -> Latitude: 56.4599834, Longitude: -2.968556624290895
# Geocoded: Cambridge Theatre, London -> Latitude: 51.513626, Longitude: -0.12654592231642325
# Geocoded: City Hall, Hong Kong -> Latitude: 22.2818804, Longitude: 114.1615384
# Geocoded: City Hall, Hull -> Latitude: 53.7435722, Longitude: -0.3394758
# Location not found: City Hall, Newcastle-on-Tyne
# Geocoded: City Hall, Perth -> Latitude: 56.56679835, Longitude: -3.585926079827911
# Geocoded: City Hall, Sheffield -> Latitude: 53.38084075, Longitude: -1.472432577156348
# Location not found: Civic, Knutsford
# Geocoded: Civic Hall, Bedworth -> Latitude: 52.4785921, Longitude: -1.4714829339626652
# Geocoded: Civic Hall, Nantwich -> Latitude: 53.068264299999996, Longitude: -2.5193146727065536
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Civic Hall, Solihull',), **{}).
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/ssl.py", line 1242, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/ssl.py", line 1100, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 451, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 340, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 815, in urlopen
#     return self.urlopen(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 815, in urlopen
#     return self.urlopen(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 787, in urlopen
#     retries = retries.increment(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Civic+Hall%2C+Solihull&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py", line 600, in get
#     return self.request("GET", url, **kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py", line 565, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Civic+Hall%2C+Solihull&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Civic+Hall%2C+Solihull&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Location not found: Civic Hall, Solihull
# Location not found: Civic Hall, Southampton
# Geocoded: Civic Hall, Whitehaven -> Latitude: 54.546689349999994, Longitude: -3.5862061431153807
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Civic Hall, Wolverhampton',), **{}).
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/ssl.py", line 1242, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/ssl.py", line 1100, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 451, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 340, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 815, in urlopen
#     return self.urlopen(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 815, in urlopen
#     return self.urlopen(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 787, in urlopen
#     retries = retries.increment(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Civic+Hall%2C+Wolverhampton&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py", line 600, in get
#     return self.request("GET", url, **kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py", line 565, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Civic+Hall%2C+Wolverhampton&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Civic+Hall%2C+Wolverhampton&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Geocoded: Civic Hall, Wolverhampton -> Latitude: 52.58659075, Longitude: -2.1308165862918873
# Location not found: Civic Theatre, Chesterfield
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Civic Theatre, Corby',), **{}).
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/ssl.py", line 1242, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/ssl.py", line 1100, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 451, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 340, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 815, in urlopen
#     return self.urlopen(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 815, in urlopen
#     return self.urlopen(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 787, in urlopen
#     retries = retries.increment(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Civic+Theatre%2C+Corby&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py", line 600, in get
#     return self.request("GET", url, **kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py", line 565, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Civic+Theatre%2C+Corby&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Civic+Theatre%2C+Corby&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Location not found: Civic Theatre, Corby
# Location not found: Civic Theatre, Halifax
# Geocoded: Cliffs Pavilion, Southend -> Latitude: 51.535223200000004, Longitude: 0.6969037184232711
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Co-operative Hall, Oldham',), **{}).
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/ssl.py", line 1242, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/ssl.py", line 1100, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 451, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 340, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 815, in urlopen
#     return self.urlopen(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 815, in urlopen
#     return self.urlopen(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 787, in urlopen
#     retries = retries.increment(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Co-operative+Hall%2C+Oldham&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py", line 600, in get
#     return self.request("GET", url, **kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py", line 565, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Co-operative+Hall%2C+Oldham&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Co-operative+Hall%2C+Oldham&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Location not found: Co-operative Hall, Oldham
# Location not found: College Theatre, Billingham
# Geocoded: Colston Hall, Bristol -> Latitude: 51.45470895, Longitude: -2.5982672862666463
# Location not found: Concert Hall, Bergen
# Location not found: Concert Hall, Gothenberg
# Location not found: Concert Hall, Tivoli
# Geocoded: Congress Theatre, Eastbourne -> Latitude: 50.7627894, Longitude: 0.28340345715925674
# Location not found: Conservatory Guiseppe Verdi, Milan
# Geocoded: Corn Exchange, Bedford -> Latitude: 52.136064250000004, Longitude: -0.46742707411525675
# Geocoded: Corn Exchange, King's Lynn -> Latitude: 52.7564062, Longitude: 0.39336478041473855
# Location not found: County Pavilion, Newtown
# Location not found: County Secondary School, Haverfordwest
# Location not found: County Secondary School, Llangefni
# Location not found: County Secondary School Theatre, Fishguard
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Covered Market Hall, Carlisle',), **{}).
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/ssl.py", line 1242, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/ssl.py", line 1100, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 451, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 340, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 815, in urlopen
#     return self.urlopen(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 815, in urlopen
#     return self.urlopen(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 787, in urlopen
#     retries = retries.increment(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Covered+Market+Hall%2C+Carlisle&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py", line 600, in get
#     return self.request("GET", url, **kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py", line 565, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Covered+Market+Hall%2C+Carlisle&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Covered+Market+Hall%2C+Carlisle&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Location not found: Covered Market Hall, Carlisle
# Geocoded: Crystal Palace, London -> Latitude: 51.4193664, Longitude: -0.0711328
# Location not found: Davis Theatre, Croydon
# Geocoded: De La Warr Pavilion, Bexhill-on-Sea -> Latitude: 50.837523250000004, Longitude: 0.47122965124256166
# Geocoded: De Montfort Hall, Leicester -> Latitude: 52.62502235, Longitude: -1.1220200960612958
# Geocoded: Deutsches Museum, Munich -> Latitude: 48.1300409, Longitude: 11.582908990594504
# Location not found: Diestenweg Schule, Linz
# Geocoded: Dorking Halls, Dorking -> Latitude: 51.2347671, Longitude: -0.3258118
# Location not found: Drill Hall, Macclesfield
# Geocoded: Drill Hall, Wellingborough -> Latitude: 52.30453625, Longitude: -0.692248087347942
# Location not found: Eastbrook Hall, Bradford
# Geocoded: Eden Court Theatre, Inverness -> Latitude: 57.4731036, Longitude: -4.230864222497448
# Location not found: Embassy Theatre, Peterborough
# Location not found: Empire Theatre, Cardiff
# Location not found: Empire Theatre, Dewsbury
# Location not found: Empire Theatre, Oldham
# Location not found: Empress Ballroom, Blackpool
# Geocoded: Erholungshaus, Leverkusen -> Latitude: 51.0343424, Longitude: 6.9814101
# Geocoded: Essoldo Cinema, Stretford -> Latitude: 53.4462116, Longitude: -2.3055601995158344
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Fairfield Hall, Croydon',), **{}).
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/ssl.py", line 1242, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/ssl.py", line 1100, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 451, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 340, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py", line 489, in send
#     resp = conn.urlopen(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 815, in urlopen
#     return self.urlopen(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 815, in urlopen
#     return self.urlopen(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 787, in urlopen
#     retries = retries.increment(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Fairfield+Hall%2C+Croydon&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 482, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py", line 600, in get
#     return self.request("GET", url, **kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py", line 587, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py", line 701, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py", line 565, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Fairfield+Hall%2C+Croydon&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 472, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 494, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Fairfield+Hall%2C+Croydon&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# Location not found: Fairfield Hall, Croydon
# Geocoded: Festhalle, Viersen -> Latitude: 51.25298085, Longitude: 6.391427662020734
# Geocoded: Festival Theatre, Chichester -> Latitude: 50.8429048, Longitude: -0.7772216561704477
# Geocoded: Festspielhaus, Salzburg -> Latitude: 47.7987295, Longitude: 13.040982237102769
# Geocoded: Filharmonia, Lodz -> Latitude: 51.7713322, Longitude: 19.45987410839987
# Geocoded: Filharmonia, Warsaw -> Latitude: 52.23436315, Longitude: 21.011280545053896
# Geocoded: Floral Hall, Southport -> Latitude: 53.6517693, Longitude: -3.0060319
# Location not found: Foxwood School, Leeds
# Geocoded: Free Trade Hall, Manchester -> Latitude: 53.47767965, Longitude: -2.247247210739584
# Geocoded: Gaiety Theatre, Dublin -> Latitude: 53.3403737, Longitude: -6.261642751088101
# Location not found: Gaumont Theatre, Chester
# Location not found: Gaumont Theatre, Ipswich
# Location not found: Granada Cinema, Shrewsbury
# Location not found: Grand Hall, Scarborough
# Location not found: Grand Theatre, Mansfield
# Location not found: Great Hall Penglais, Aberystwyth
# Location not found: Greenacres Hall, Oldham
# Geocoded: Grosse Musikhalle, Hamburg -> Latitude: 53.5559406, Longitude: 9.980936
# Location not found: Grosser Kuppelsaal, Hannover
# Location not found: Grossermusikvereinsaal, Vienna
# Location not found: Grossersaal Mozarteum, Salzburg
# Location not found: Grosvenor Hall, Belfast
# Geocoded: Guild Hall, Preston -> Latitude: 53.75970745, Longitude: -2.696808554707215
# Geocoded: Guildhall, Bath -> Latitude: 51.38210155, Longitude: -2.358772899376806
# Geocoded: Guildhall, Cambridge -> Latitude: 52.2047526, Longitude: 0.11927031643356645
# Geocoded: Guildhall, Derry/Londonderry -> Latitude: 54.99760259999999, Longitude: -7.319395670905091
# Geocoded: Guildhall, London -> Latitude: 51.51590665, Longitude: -0.09202398601739807
# Geocoded: Guildhall, Portsmouth -> Latitude: 50.7972525, Longitude: -1.0920802648880952
# Geocoded: Guildhall, Southampton -> Latitude: 50.90798995, Longitude: -1.4060055634934607
# Location not found: Happy Valley, Episcopi
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Heidelberg, Staadthalle',), **{}).
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 449, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 444, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 1377, in getresponse
#     response.begin()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 320, in begin
#     version, status, reason = self._read_status()
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/http/client.py", line 281, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/ssl.py", line 1242, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/ssl.py", line 1100, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/danielgonzalez/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py", line 451, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
# ...
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=
# Geocoded: Winter Gardens, Bournemouth -> Latitude: 50.7181366, Longitude: -1.8805734
# Geocoded: Winter Gardens, Eastbourne -> Latitude: 50.7627855, Longitude: 0.285183
# Geocoded: Winter Gardens, Malvern -> Latitude: 51.5192851, Longitude: 0.5611774
# Geocoded: Winter Gardens, Margate -> Latitude: 51.3916599, Longitude: 1.3867389
# Geocoded: Winter Gardens, Morecambe -> Latitude: 54.0720903, Longitude: -2.870984696849636
#           Venue Name   Venue Town  \
# 0         ABC Cinema  Northampton
# 1        ABC Theatre    Blackpool
# 2       Abbey Cinema      Wexford
# 3         Abbey Road       London
# 4    Adam Smith Hall     Kirkaldy
# ..               ...          ...
# 370   Winter Gardens  Bournemouth
# 371   Winter Gardens   Eastbourne
# 372   Winter Gardens      Malvern
# 373   Winter Gardens      Margate
# 374   Winter Gardens    Morecambe
#
#                                               concerts  concert_count  \
# 0    [{'concert_id': 6162, 'date': '1969-03-02', 'p...              1
# 1    [{'concert_id': 7143, 'date': '1976-06-06', 'p...              1
# 2    [{'concert_id': 4394, 'date': '1958-10-26', 'p...              1
# 3    [{'concert_id': 2555, 'date': '1948-12-02', 'p...             20
# 4    [{'concert_id': 1964, 'date': '1946-06-19', 'p...              5
# ..                                                 ...            ...
# 370  [{'concert_id': 3042, 'date': '1952-06-06', 'p...             10
# 371  [{'concert_id': 2503, 'date': '1949-05-28', 'p...              1
# 372  [{'concert_id': 7500, 'date': '1978-06-04', 'p...              1
# 373  [{'concert_id': 4939, 'date': '1962-04-29', 'p...              3
# 374  [{'concert_id': 2196, 'date': '1947-01-19', 'p...              6
#
#       latitude  longitude
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN        NaN
# 3    51.532541   0.003609
# 4          NaN        NaN
# ..         ...        ...
# 370  50.718137  -1.880573
# 371  50.762785   0.285183
# 372  51.519285   0.561177
# 373  51.391660   1.386739
# 374  54.072090  -2.870985
#
# [375 rows x 6 columns]

# %%
venues.dropna(inplace=True)

# %%
# Custom function to format data correctly
def format_data(row):
    return {
        "venue_name": row['Venue Name'],
        "venue_town": row['Venue Town'],
        "latitude": row['latitude'],
        "longitude": row['longitude'],
        "concerts": row['concerts'],
        "concert_count": row['concert_count']
    }

# Apply the function and convert to JSON
formatted_data = venues.apply(format_data, axis=1).tolist()
import json
json_output = json.dumps(formatted_data, indent=4)  # indent for pretty printing

# %%
# Write JSON data to a file
with open('venue_data_new.json', 'w') as f:
    f.write(json_output)

# %%
geojson = {
    "type": "FeatureCollection",
    "features": [
        {
            "type": "Feature",
            "geometry": {
                "type": "Point",
                "coordinates": [venue["longitude"], venue["latitude"]]
            },
            "properties": {
                "venue_name": venue["venue_name"],
                "venue_town": venue["venue_town"],
                "concert_count": venue["concert_count"]
            }  # You might want to omit or modify this line to exclude specific properties
        } for venue in formatted_data
    ]
}

# %%
# Write GeoJSON to a file
with open('venues.geojson', 'w') as file:
    json.dump(geojson, file, indent=4)
